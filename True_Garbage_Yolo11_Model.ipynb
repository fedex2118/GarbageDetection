# %% [markdown]
# <a href="https://colab.research.google.com/github/fedex2118/GarbageDetection/blob/main/True_Garbage_Yolo11_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Install Dependencies

# %%
from IPython.display import Image, display
# clone YOLOv11 repository
# !pip install ultralytics

# %%
# !pip install roboflow
# Out:
# ...
#                                               0.0/89.9 kB ? eta -:--:--
#      --------                               20.5/89.9 kB 682.7 kB/s eta 0:00:01
#      ---------------------                  51.2/89.9 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 89.9/89.9 kB 637.6 kB/s eta 0:00:00
# ...
#                                               0.0/38.8 MB ? eta -:--:--
#                                               0.2/38.8 MB 3.5 MB/s eta 0:00:12
#                                               0.5/38.8 MB 4.2 MB/s eta 0:00:10
#      -                                        1.0/38.8 MB 6.3 MB/s eta 0:00:06
#      --                                       2.0/38.8 MB 9.6 MB/s eta 0:00:04
#      ---                                      3.5/38.8 MB 14.0 MB/s eta 0:00:03
#      -----                                    5.0/38.8 MB 16.9 MB/s eta 0:00:03
#      -----                                    5.1/38.8 MB 14.7 MB/s eta 0:00:03
# ...

# %%
# install dependencies as necessary
import torch

from IPython.display import Image, clear_output  # to display images

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 2.9.1+cu126 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3060', major=8, minor=6, total_memory=12287MB, multi_processor_count=28, uuid=f15346d5-6b41-c4cc-c8fd-a41a63fdd5c1, pci_bus_id=1, pci_device_id=0, pci_domain_id=0, L2_cache_size=2MB)

# %% [markdown]
# This is the for the original dataset used to train Yolov5

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data
from roboflow import Roboflow
rf = Roboflow(api_key="raifJZV5ydW0w0mCsbV3")
project = rf.workspace("material-identification").project("garbage-classification-3")
version = project.version(2)
dataset = version.download("yolov11")

# %% [markdown]
# This is the for the new dataset used to train yolov5

# %%
# this is the YAML file Roboflow wrote for us that we're loading into this notebook with our data

from roboflow import Roboflow
rf = Roboflow(api_key="fjcIAf6clQ73LrRJ4kTZ")
project = rf.workspace("yolo-lvle4").project("waste-fx8bs")
version = project.version(5)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# #Train Model

# %%
from ultralytics import YOLO
#import sys
#sys.path
#sys.path.append('/content/')

# Load a model
## Changes the model
model = YOLO("yolo11s.pt")

# Train the model
train_results = model.train(
    data=f"{dataset.location}/data.yaml",  # path to dataset YAML
    epochs=100,  # number of training epochs
    imgsz= 640, # training image size (640/416)
    batch = -1, #de
    cache = False,
    device="0",  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
    workers = 0, # Same problem as before
)

# Evaluate model performance on the validation set
metrics = model.val()

print(metrics)
# Out:
# ...
# New https://pypi.org/project/ultralytics/8.3.249 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.246  Python-3.10.19 torch-2.9.1+cu126 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %% [markdown]
# Model inference

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model by passing the path to the final weights of the training
model = YOLO(".\best.pt")

# Define path to directory containing images and videos for inference
source = ".\testNoCambodia"

# Run inference on the source (decide path and imagesize based on dataset)

model.predict(source, save=True, imgsz=416, project = '.\\runs\\detect\\PredictNewDataset' )
